# %%
import pandas as pd
import numpy as np

# %%
recipes_df = pd.read_csv("data/Foodcom/recipes.csv")
reviews_df = pd.read_csv("data/Foodcom/reviews.csv")

# %%
print(recipes_df.shape)
recipes_df.info()
recipes_df.head()
# Out:
# (522517, 29)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 522517 entries, 0 to 522516
# Data columns (total 29 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Unnamed: 0                  522517 non-null  int64
#  1   RecipeId                    522517 non-null  int64
#  2   Name                        522517 non-null  object
#  3   AuthorId                    522517 non-null  int64
#  4   AuthorName                  522517 non-null  object
#  5   CookTime                    439972 non-null  object
#  6   PrepTime                    522517 non-null  object
#  7   TotalTime                   522517 non-null  object
#  8   DatePublished               522517 non-null  object
#  9   Description                 522512 non-null  object
#  10  Images                      522516 non-null  object
#  11  RecipeCategory              521766 non-null  object
# ...

# %%
reviews_df.info()
reviews_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1401982 entries, 0 to 1401981
# Data columns (total 8 columns):
#  #   Column         Non-Null Count    Dtype
# ---  ------         --------------    -----
#  0   ReviewId       1401982 non-null  int64
#  1   RecipeId       1401982 non-null  int64
#  2   AuthorId       1401982 non-null  int64
#  3   AuthorName     1401982 non-null  object
#  4   Rating         1401982 non-null  int64
#  5   Review         1401768 non-null  object
#  6   DateSubmitted  1401982 non-null  object
#  7   DateModified   1401982 non-null  object
# dtypes: int64(4), object(4)
# memory usage: 85.6+ MB
#    ReviewId  RecipeId  AuthorId        AuthorName  Rating  \
# 0         2       992      2008         gayg msft       5
# 1         7      4384      1634     Bill Hilbrich       4
# 2         9      4523      2046  Gay Gilmore ckpt       2
# 3        13      7435      1773     Malarkey Test       5
# 4        14        44      2085        Tony Small       5
# ...
